# %%
import geopandas as gpd

# %%
# file_path = "/home/tim/Programmieren/Projekte/data-ambassadors-parking-pr/data/friedrichshain-kreuzberg/cartagger_polygons_per_counted_parking_f-kr.geojson"
file_path = "/home/tim/Programmieren/Projekte/data-ambassadors-parking-pr/data/raw/friedrichshain-kreuzberg/cartagger_polygons_per_counted_parking_f-kr.geojson"

# %%
# Read file using gpd.read_file()
cartagger_fk = gpd.read_file(file_path)

# %%
cartagger_fk.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8767 entries, 0 to 8766
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   condition             8617 non-null   object
#  1   parking               8767 non-null   object
#  2   orientation           8767 non-null   object
#  3   condition:other       193 non-null    object
#  4   position              8763 non-null   object
#  5   condition:other:time  191 non-null    object
#  6   source:capacity       8767 non-null   object
#  7   oneway_direction      248 non-null    object
#  8   highway               8767 non-null   object
#  9   highway:name          8741 non-null   object
#  10  maxstay               34 non-null     object
#  11  capacity              8767 non-null   int64
#  12  osm-location          8767 non-null   object
#  13  osm_id                8767 non-null   object
# ...

# %%
cartagger_fk.head(40)
# Out:
#    condition      parking    orientation condition:other     position  \
# 0       free  street_side  perpendicular            None  street_side
# 1       free  street_side       parallel            None  street_side
# 2       free  street_side       diagonal            None  street_side
# 3       free  street_side       diagonal            None  street_side
# 4       free  street_side       diagonal            None  street_side
# 5       free  street_side       diagonal            None  street_side
# 6       free  street_side       diagonal            None  street_side
# 7       free  street_side       diagonal            None  street_side
# 8       free  street_side       diagonal            None  street_side
# 9       free  street_side       diagonal            None  street_side
# 10      free  street_side       diagonal            None  street_side
# 11      free  street_side       diagonal            None  street_side
# ...

# %%
cartagger_fk.columns
# Out:
# Index(['condition', 'parking', 'orientation', 'condition:other', 'position',
#        'condition:other:time', 'source:capacity', 'oneway_direction',
#        'highway', 'highway:name', 'maxstay', 'capacity', 'osm-location',
#        'osm_id', 'id', 'length', 'size', 'inMotion', 'geometry'],
#       dtype='object')

# %%
world = world[['continent', 'geometry']]

# %%
continents = cartagger_fk.dissolve(by='id', aggfunc='sum')

# %%
new = cartagger_fk.groupby(['id']) #.size()

# %%
new.sum().info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5210 entries, 1 to 5210
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   capacity  5210 non-null   int64
#  1   length    5210 non-null   float64
#  2   inMotion  5210 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 291.9 KB

# %%
df = cartagger_fk.groupby(['id']).size()

# %%
df.head(10)
# Out:
# id
# 1      1
# 2      1
# 3     32
# 4      6
# 5      2
# 6      2
# 7      5
# 8      1
# 9      1
# 10     1
# dtype: int64

# %%
print(pd.merge(df1, df2, left_on='id', right_on='id1', how='left').drop('id1', axis=1))

# %%
cartagger_fk['cartagger_count'] = cartagger_fk.id.map(df.index['cartagger_count'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-1ed425caa139> in <module>
# ----> 1 cartagger_fk['cartagger_count'] = cartagger_fk.id.map(df.index['cartagger_count'])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4295         if is_scalar(key):
#    4296             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4297             return getitem(key)
#    4298
#    4299         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
cartagger_fk['cartagger_count'][3]
